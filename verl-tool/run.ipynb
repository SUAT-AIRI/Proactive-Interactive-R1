# %%
import subprocess
import time
command = f"""bash examples/train/proactive_interactive_r1/run_train_interacitve_7b_collab_math_large_us_llama-3.1-8B.sh"""
import random
random_number = random.randint(1, 100000)
print(f"random_number->{random_number}")
with open(f"logs/output_{random_number}.log", "w") as outfile:
    process = subprocess.Popen(command, shell=True, stdout=outfile, stderr=subprocess.STDOUT)
print(f"Process ID: {process.pid}")
# Out:
# random_number->86218
# Process ID: 2564269

# %%
# !pkill -f ray

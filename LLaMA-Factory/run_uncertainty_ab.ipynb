# %%
import subprocess
import time 

command = f"""CUDA_VISIBLE_DEVICES=0,1,2,3 NCCL_P2P_LEVEL=NVL FORCE_TORCHRUN=1 llamafactory-cli train /home/chenxin/proactive_interactive_r1/LLaMA-Factory/run/ab_uncertainty/top_20p.yaml"""

import random
random_number = random.randint(1, 100000)
print(f"random_number->{random_number}")
with open(f"logs/output_{random_number}.log", "w") as outfile:
    process = subprocess.Popen(command, shell=True, stdout=outfile, stderr=subprocess.STDOUT)
print(f"Process ID: {process.pid}")
# Out:
# random_number->81331
# Process ID: 4025204

# %% [markdown]
# ## SFT Model

# %%
import subprocess
import time 

command = f"""CUDA_VISIBLE_DEVICES=1,2,6,7 NCCL_P2P_LEVEL=NVL FORCE_TORCHRUN=1 llamafactory-cli train run/distill-qwen-7b_full_sft.yaml"""
import random
random_number = random.randint(1, 100000)
print(f"random_number->{random_number}")
with open(f"logs/output_{random_number}.log", "w") as outfile:
    process = subprocess.Popen(command, shell=True, stdout=outfile, stderr=subprocess.STDOUT)
print(f"Process ID: {process.pid}")
# Out:
# random_number->8406
# Process ID: 1433446

# %%
import subprocess
import time 

command = f"""CUDA_VISIBLE_DEVICES=1,2,6,7 NCCL_P2P_LEVEL=NVL FORCE_TORCHRUN=1 llamafactory-cli train run/w_sys/distill-qwen-7b_full_sft_4k.yaml"""

import random
random_number = random.randint(1, 100000)
print(f"random_number->{random_number}")
with open(f"logs/output_{random_number}.log", "w") as outfile:
    process = subprocess.Popen(command, shell=True, stdout=outfile, stderr=subprocess.STDOUT)
print(f"Process ID: {process.pid}")
# Out:
# random_number->87604
# Process ID: 369029

# %%
import subprocess
import time 

command = f"""python auto_run.py"""

import random
random_number = random.randint(1, 100000)
print(f"random_number->{random_number}")
with open(f"logs/output_{random_number}.log", "w") as outfile:
    process = subprocess.Popen(command, shell=True, stdout=outfile, stderr=subprocess.STDOUT)
print(f"Process ID: {process.pid}")
# Out:
# random_number->74368
# Process ID: 110520
